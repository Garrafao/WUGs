# %%
import requests
import pandas as pd
import io
import numpy as np
import os
import warnings
import csv

# !pip install fuzzywuzzy
import fuzzywuzzy

from fuzzywuzzy import fuzz
import re

warnings.filterwarnings("ignore")
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# Requirement already satisfied: fuzzywuzzy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.18.0)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -egex (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
URL = "https://raw.githubusercontent.com/seantrott/raw-c/main/data/processed/raw-c_with_dominance.csv"
download = requests.get(URL).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')),sep = ',')

# %%
df.head()
# Out:
#    Unnamed: 0 word                sentence1              sentence2   same  \
# 0           0  act  It was a desperate act.    It was a magic act.  False
# 1           1  act  It was a desperate act.  It was a comedic act.  False
# 2           2  act     It was a humane act.    It was a magic act.  False
# 3           3  act     It was a humane act.  It was a comedic act.  False
# 4           4  act  It was a desperate act.   It was a humane act.   True
#
#   ambiguity_type disambiguating_word1 disambiguating_word2    version Class  \
# 0       Polysemy            desperate                magic  M1_a_M2_a     N
# 1       Polysemy            desperate              comedic  M1_a_M2_b     N
# 2       Polysemy               humane                magic  M1_b_M2_a     N
# 3       Polysemy               humane              comedic  M1_b_M2_b     N
# 4       Polysemy            desperate               humane  M1_a_M1_b     N
#
#    ...      diff  count  sd_relatedness  distance_bert  distance_elmo  \
# 0  ...  0.181818     11        1.328020       0.204110       0.034093
# 1  ...  0.000000      7        1.290994       0.215616       0.045927
# 2  ...  0.181818     11        0.981650       0.191488       0.042351
# 3  ...  0.190476     21        0.928388       0.225272       0.057707
# 4  ...  0.100000     10        0.316228       0.167990       0.041440
#
#    se_relatedness    v1    v2 dominance_sentence2 sd_dominance_sentence2
# 0        0.400413  M1_a  M2_a           -0.533333               1.187234
# 1        0.487950  M1_a  M2_b            0.176471               1.467791
# 2        0.295979  M1_b  M2_a            0.103448               1.519982
# 3        0.202591  M1_b  M2_b           -0.411765               1.543487
# 4        0.100000  M1_a  M1_b                 NaN                    NaN
#
# [5 rows x 22 columns]

# %%
df_dash = df[['word', 'sentence1', 'sentence2', "Class"]]

# %%
df1 = df_dash[['word', 'sentence1', 'Class']]
df1.columns =  ['word', 'sent', 'class']
df1["index"] = df1.groupby("word").cumcount()*2

# %%
df2 =  df_dash[['word', 'sentence2', 'Class']]
df2.columns =  ['word', 'sent', 'class']
df2["index"] = df2.groupby("word").cumcount()*2+1

# %%
df_final = pd.concat([df1, df2])
df_final = df_final.sort_values(by = ['word', 'index'], ascending = [True, True])

# %%
df_final["identifier"] = df_final["word"]+"-"+df_final["index"].astype(str)

# %%
df_odd = df_final[1::2]
df_odd.columns = ["word2", "sent2", 'class2', "index2", "identifier2"]
df_even = df_final[::2]
df_even.columns = ["word1", "sent1", "class1", "index1", "identifier1"]
df_final = pd.concat([df_even, df_odd], axis=1)

# %%
df_final = df_final[["word2", "sent2", "identifier2", 'class2', "sent1", "identifier1", 'class1', 'index1', 'index2']]
df_final_next_stage = df_final.rename(columns={"word2":"lemma"})

# %%
df_final = df_final_next_stage

# %%
df_final_next_stage
# Out:
#     lemma                       sent2 identifier2 class2  \
# 0     act         It was a magic act.       act-1      N
# 1     act       It was a comedic act.       act-3      N
# 2     act         It was a magic act.       act-5      N
# 3     act       It was a comedic act.       act-7      N
# 4     act        It was a humane act.       act-9      N
# ..    ...                         ...         ...    ...
# 667  yard  They were cluttered yards.      yard-3      N
# 668  yard        They were big yards.      yard-5      N
# 669  yard  They were cluttered yards.      yard-7      N
# 670  yard           It was ten yards.      yard-9      N
# 671  yard  They were cluttered yards.     yard-11      N
#
#                        sent1 identifier1 class1  index1  index2
# 0    It was a desperate act.       act-0      N       0       1
# 1    It was a desperate act.       act-2      N       2       3
# 2       It was a humane act.       act-4      N       4       5
# 3       It was a humane act.       act-6      N       6       7
# 4    It was a desperate act.       act-8      N       8       9
# ..                       ...         ...    ...     ...     ...
# 667       It was five yards.      yard-2      N       2       3
# 668        It was ten yards.      yard-4      N       4       5
# 669        It was ten yards.      yard-6      N       6       7
# 670       It was five yards.      yard-8      N       8       9
# 671     They were big yards.     yard-10      N      10      11
#
# [672 rows x 9 columns]

# %%
df_final["judgment"] = df["same"].values.tolist()

# %%
df_final = df_final[['lemma', 'identifier2', 'identifier1', 'judgment']]

# %%
df_final["annotator"] = " "
df_final["comment"] = df['ambiguity_type']

# %%
df_final = df_final[["identifier1", "identifier2", "annotator", "judgment", "comment", "lemma"]]

# %%
df_final.head()
# Out:
#   identifier1 identifier2 annotator  judgment   comment lemma
# 0       act-0       act-1               False  Polysemy   act
# 1       act-2       act-3               False  Polysemy   act
# 2       act-4       act-5               False  Polysemy   act
# 3       act-6       act-7               False  Polysemy   act
# 4       act-8       act-9                True  Polysemy   act

# %%
df_final.to_csv('st_judge.csv', sep='\t', encoding='utf-8', quoting = csv.QUOTE_NONE, quotechar='')

# %%
for i in list(df_final["lemma"].value_counts().index):
    df_temp = df_final[df_final["lemma"]==i]
    numpy_df = df_temp.to_numpy()
    header = list(df_temp.columns)
    numpy_df = np.vstack([header, numpy_df])
    if not os.path.exists(i):
        os.mkdir(i)
    np.savetxt(i+"/judgments.csv", numpy_df,fmt='%s', delimiter='\t')

# %%
df.head()
# Out:
#    Unnamed: 0 word                sentence1              sentence2   same  \
# 0           0  act  It was a desperate act.    It was a magic act.  False
# 1           1  act  It was a desperate act.  It was a comedic act.  False
# 2           2  act     It was a humane act.    It was a magic act.  False
# 3           3  act     It was a humane act.  It was a comedic act.  False
# 4           4  act  It was a desperate act.   It was a humane act.   True
#
#   ambiguity_type disambiguating_word1 disambiguating_word2    version Class  \
# 0       Polysemy            desperate                magic  M1_a_M2_a     N
# 1       Polysemy            desperate              comedic  M1_a_M2_b     N
# 2       Polysemy               humane                magic  M1_b_M2_a     N
# 3       Polysemy               humane              comedic  M1_b_M2_b     N
# 4       Polysemy            desperate               humane  M1_a_M1_b     N
#
#    ...      diff  count  sd_relatedness  distance_bert  distance_elmo  \
# 0  ...  0.181818     11        1.328020       0.204110       0.034093
# 1  ...  0.000000      7        1.290994       0.215616       0.045927
# 2  ...  0.181818     11        0.981650       0.191488       0.042351
# 3  ...  0.190476     21        0.928388       0.225272       0.057707
# 4  ...  0.100000     10        0.316228       0.167990       0.041440
#
#    se_relatedness    v1    v2 dominance_sentence2 sd_dominance_sentence2
# 0        0.400413  M1_a  M2_a           -0.533333               1.187234
# 1        0.487950  M1_a  M2_b            0.176471               1.467791
# 2        0.295979  M1_b  M2_a            0.103448               1.519982
# 3        0.202591  M1_b  M2_b           -0.411765               1.543487
# 4        0.100000  M1_a  M1_b                 NaN                    NaN
#
# [5 rows x 22 columns]

# %%
df1 = df_final_next_stage[['lemma', 'sent1', 'class1', 'identifier1', 'index1']]
df1.columns =  ['word', 'sent', 'pos', 'identifier', 'index']
df2 = df_final_next_stage[['lemma', 'sent2', 'class2', 'identifier2', 'index2']]
df2.columns =  ['word', 'sent', 'pos', 'identifier', 'index']

# %%
df_final = pd.concat([df1, df2])

# %%
df_final.head()
# Out:
#   word                     sent pos identifier  index
# 0  act  It was a desperate act.   N      act-0      0
# 1  act  It was a desperate act.   N      act-2      2
# 2  act     It was a humane act.   N      act-4      4
# 3  act     It was a humane act.   N      act-6      6
# 4  act  It was a desperate act.   N      act-8      8

# %%
df_final = df_final.reset_index(drop = True)

# %%
from fuzzywuzzy import process
tag = ''
def get_indices_of_tags(sentence, word):
    i = sentence.split(" ")
    tag = process.extractOne(word, i)
    tag = tag[0]
   #print(tag)
    tag = re.sub('\W+', '', tag)
    return(str(sentence.find(tag))+":"+str(sentence.find(tag)+len(tag)))

# %%
def get_target(sentence, word):
    tok = sentence.split(" ")
    tag = process.extractOne(word, tok)
    tag = tag[0]
   #print(tag)
    for i in tok:
        if tag == i:
            ind = tok.index(i)
    return ind

# %%
df_final["indexes_target_token"] = df_final.apply(lambda x: get_indices_of_tags(x.sent, x.word), axis=1)

# %%
df_final['indexes_target_token_tokenized'] = df_final.apply(lambda x: get_target(x.sent, x.word), axis=1)

# %%
df_final.head()
# Out:
#   word                     sent pos identifier  index indexes_target_token  \
# 0  act  It was a desperate act.   N      act-0      0                19:22
# 1  act  It was a desperate act.   N      act-2      2                19:22
# 2  act     It was a humane act.   N      act-4      4                16:19
# 3  act     It was a humane act.   N      act-6      6                16:19
# 4  act  It was a desperate act.   N      act-8      8                19:22
#
#    indexes_target_token_tokenized
# 0                               4
# 1                               4
# 2                               4
# 3                               4
# 4                               4

# %%
def get_indices_of_sent(sentence):
    return "0:"+str(len(sentence))

# %%
df_final["indexes_target_sentence"] = df_final["sent"].apply(get_indices_of_sent)

# %%
df_final = df_final.rename(columns = {"sent":"context", "word":"lemma"})

# %%
df_final['description'] = " "
df_final['date'] = "NaN"
df_final['grouping'] = "1"

# %%
df_final = df_final[['lemma', 'pos', 'date', 'grouping', 'identifier', 'description', 'context', 'indexes_target_token', 'indexes_target_sentence', 'indexes_target_token_tokenized', 'index' ]]

# %%
df_final
# Out:
#      lemma pos date grouping identifier description  \
# 0      act   N  NaN        1      act-0
# 1      act   N  NaN        1      act-2
# 2      act   N  NaN        1      act-4
# 3      act   N  NaN        1      act-6
# 4      act   N  NaN        1      act-8
# ...    ...  ..  ...      ...        ...         ...
# 1339  yard   N  NaN        1     yard-3
# 1340  yard   N  NaN        1     yard-5
# 1341  yard   N  NaN        1     yard-7
# 1342  yard   N  NaN        1     yard-9
# 1343  yard   N  NaN        1    yard-11
#
#                          context indexes_target_token indexes_target_sentence  \
# 0        It was a desperate act.                19:22                    0:23
# 1        It was a desperate act.                19:22                    0:23
# 2           It was a humane act.                16:19                    0:20
# 3           It was a humane act.                16:19                    0:20
# 4        It was a desperate act.                19:22                    0:23
# ...                          ...                  ...                     ...
# 1339  They were cluttered yards.                20:25                    0:26
# 1340        They were big yards.                14:19                    0:20
# 1341  They were cluttered yards.                20:25                    0:26
# 1342           It was ten yards.                11:16                    0:17
# 1343  They were cluttered yards.                20:25                    0:26
#
#       indexes_target_token_tokenized  index
# 0                                  4      0
# 1                                  4      2
# 2                                  4      4
# 3                                  4      6
# 4                                  4      8
# ...                              ...    ...
# 1339                               3      3
# 1340                               3      5
# 1341                               3      7
# 1342                               3      9
# 1343                               3     11
#
# [1344 rows x 11 columns]

# %%
df_final['context_tokenized'] = df_final['context']

# %%
def get_len_tok(sentence):
    return "0:"+str(len(sentence.split(" ")))

# %%
df_final['indexes_target_sentence_tokenized'] = df_final["context_tokenized"].apply(get_len_tok)

# %%
lem = ''
def lemmatizr(sent):
    doc = nlp(sent)
    for i in doc:
        lem += i.lemma_
    return lem

# %%
df_final['context_lemmatized'] = df_final["context_tokenized"].apply(lambda row: " ".join([w.lemma_ for w in nlp(row)]))

# %%
df_final['context_pos'] = df_final["context_tokenized"].apply(lambda row: " ".join([w.pos_ for w in nlp(row)]))

# %%
final_df = df_final[['lemma', 'pos', 'date', 'grouping', 'identifier', 'description', 'context', 'indexes_target_token', 'indexes_target_sentence', 'context_tokenized', 'indexes_target_token_tokenized', 'indexes_target_sentence_tokenized', 'context_lemmatized', 'context_pos', 'index']]

# %%
final_df = df_final.sort_values(by = ['lemma', 'index'], ascending = [True, True]).drop("index", axis=1)

# %%
final_df = final_df.reset_index(drop = True)

# %%
final_df
# Out:
#      lemma pos date grouping identifier description  \
# 0      act   N  NaN        1      act-0
# 1      act   N  NaN        1      act-1
# 2      act   N  NaN        1      act-2
# 3      act   N  NaN        1      act-3
# 4      act   N  NaN        1      act-4
# ...    ...  ..  ...      ...        ...         ...
# 1339  yard   N  NaN        1     yard-7
# 1340  yard   N  NaN        1     yard-8
# 1341  yard   N  NaN        1     yard-9
# 1342  yard   N  NaN        1    yard-10
# 1343  yard   N  NaN        1    yard-11
#
#                          context indexes_target_token indexes_target_sentence  \
# 0        It was a desperate act.                19:22                    0:23
# 1            It was a magic act.                15:18                    0:19
# 2        It was a desperate act.                19:22                    0:23
# 3          It was a comedic act.                17:20                    0:21
# 4           It was a humane act.                16:19                    0:20
# ...                          ...                  ...                     ...
# 1339  They were cluttered yards.                20:25                    0:26
# 1340          It was five yards.                12:17                    0:18
# 1341           It was ten yards.                11:16                    0:17
# 1342        They were big yards.                14:19                    0:20
# 1343  They were cluttered yards.                20:25                    0:26
#
#       indexes_target_token_tokenized           context_tokenized  \
# 0                                  4     It was a desperate act.
# 1                                  4         It was a magic act.
# 2                                  4     It was a desperate act.
# 3                                  4       It was a comedic act.
# 4                                  4        It was a humane act.
# ...                              ...                         ...
# 1339                               3  They were cluttered yards.
# 1340                               3          It was five yards.
# 1341                               3           It was ten yards.
# 1342                               3        They were big yards.
# 1343                               3  They were cluttered yards.
#
#      indexes_target_sentence_tokenized        context_lemmatized  \
# 0                                  0:5   it be a desperate act .
# 1                                  0:5       it be a magic act .
# 2                                  0:5   it be a desperate act .
# 3                                  0:5     it be a comedic act .
# 4                                  0:5      it be a humane act .
# ...                                ...                       ...
# 1339                               0:4  they be cluttered yard .
# 1340                               0:4         it be five yard .
# 1341                               0:4          it be ten yard .
# 1342                               0:4        they be big yard .
# 1343                               0:4  they be cluttered yard .
#
#                       context_pos
# 0     PRON AUX DET ADJ NOUN PUNCT
# 1     PRON AUX DET ADJ NOUN PUNCT
# 2     PRON AUX DET ADJ NOUN PUNCT
# 3     PRON AUX DET ADJ NOUN PUNCT
# 4     PRON AUX DET ADJ NOUN PUNCT
# ...                           ...
# 1339      PRON AUX ADJ NOUN PUNCT
# 1340      PRON AUX NUM NOUN PUNCT
# 1341      PRON AUX NUM NOUN PUNCT
# 1342      PRON AUX ADJ NOUN PUNCT
# 1343      PRON AUX ADJ NOUN PUNCT
#
# [1344 rows x 14 columns]

# %%
sent = 'They liked the friendly lamb.'
sent1 = sent.split(" ")
sent1
# Out:
# ['They', 'liked', 'the', 'friendly', 'lamb.']

# %%
final_df.to_csv('st.csv', sep='\t', encoding='utf-8', quoting = csv.QUOTE_NONE, quotechar='')

# %%
for i in list(final_df["lemma"].value_counts().index):
    df_temp = final_df[final_df["lemma"]==i]
    numpy_df = df_temp.to_numpy()
    header = list(df_temp.columns)
    numpy_df = np.vstack([header, numpy_df])
    if not os.path.exists(i):
        os.mkdir(i)
    np.savetxt(i+"/uses.csv", numpy_df,fmt='%s', delimiter='\t')
