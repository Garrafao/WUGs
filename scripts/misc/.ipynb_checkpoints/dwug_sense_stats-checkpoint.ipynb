# %% [markdown]
# ## Introduction
# This notebook loads DWUG DE's additional sense annotation and creates cluster stats and change scores.

# %%
# import scripts from parent folder
import sys
sys.path.append('../')

import os
from pathlib import Path

output_path = 'dwug_de_sense'
Path(output_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Load data

# %%
# reference data set for experiments: DWUG DE (V2.0.0)
import requests
dwug_de = 'https://zenodo.org/record/5796871/files/dwug_de.zip?download=1'
r = requests.get(dwug_de, allow_redirects=True)
f = 'dwug_de.zip'
open(f, 'wb').write(r.content)

import zipfile
with zipfile.ZipFile(f) as z:
    z.extractall()

# %%
import pandas as pd
from pathlib import Path
import numpy as np

# big dataset
dataset_path = 'dwug_de'

# Extract grouping (time) information
df_dwug_de_uses = pd.DataFrame()
for p in Path(dataset_path+'/data').glob('*/uses.csv'):
    df_dwug_de_uses = pd.concat([df_dwug_de_uses, pd.read_csv(p, delimiter='\t', quoting=3)])
display(df_dwug_de_uses)
# Out:
#             lemma    pos  date  grouping  \
# 0    voranstellen  VVIZU  1891         1
# 1    voranstellen  VVFIN  1870         1
# 2    voranstellen   VVPP  1895         1
# 3    voranstellen  VVINF  1834         1
# 4    voranstellen   VVPP  1846         1
# ..            ...    ...   ...       ...
# 195         Titel     NN  1955         2
# 196         Titel     NN  1964         2
# 197         Titel     NN  1955         2
# 198         Titel     NN  1973         2
# 199         Titel     NN  1966         2
#
#                                   identifier description  \
# 0             lehnert_seehaefen01_1891-30-14
# 1        schmoller_kleingewerbe_1870-6005-25
# 2              schroeder_logik03_1895-1006-4
# 3           wienbarg_plattdeutsch_1834-104-8
# 4            vischer_aesthetik01_1846-511-62
# ..                                       ...         ...
# 195   26120215_1955_02_04_01_013.tcf.xml-8-6
# 196  26120215_1964_04_22_01_110.tcf.xml-15-9
# 197  26120215_1955_05_21_02_133.tcf.xml-13-5
# 198  2532889X_1973-09-18_01_077.tcf.xml-5-14
# 199   2532889X_1966-05-09_01_147.tcf.xml-3-5
#
#                                                context indexes_target_token  \
# 0    Von der ursprünglichen Absicht, demselben als ...              107:121
# 1    Sie ist dann berechtigt und steht mit der ganz...              157:168
# 2    Als ganz fundamental sei vorangestellt der Sat...                25:38
# 3    Muß ich nicht Luther selbst und die Reformatio...                48:60
# 4    Es kann z. B. eine Philosophie ein verhältnißm...              386:399
# ..                                                 ...                  ...
# 195  Erstmalig wurde auch aktiven Sportlern der Tit...                43:48
# 196  Die besten Judoka aus 18 Ländern streben nach ...                50:55
# 197  Mehrfach holte er sich den Titel eines Speedwa...                27:32
# 198  war Meister Alexander Tschutkich aus dem Krasn...              110:115
# 199  lr lieben daa Leben dieser Titel der dem 20. J...                27:32
#
#     indexes_target_sentence  \
# 0                     0:207
# 1                     0:182
# 2                     0:326
# 3                      0:61
# 4                     0:497
# ..                      ...
# 195                   0:138
# 196                    0:81
# 197                    0:66
# 198                   0:156
# 199                   0:169
#
#                                      context_tokenized  \
# 0    Von der ursprünglichen Absicht , demselben als...
# 1    Sie iſt dann berechtigt und ſteht mit der ganz...
# 2    Als ganz fundamental sei vorangestellt der Sat...
# 3    Muß ich nicht Luther selbst und die Reformatio...
# 4    Es kann z. B. eine Philoſophie ein verhältnißm...
# ..                                                 ...
# 195  Erstmalig wurde auch aktiven Sportlern der Tit...
# 196  Die besten Judoka aus 18 Ländern streben nach ...
# 197  Mehrfach holte er sich den Titel eines Speedwa...
# 198  war Meister Alexander Tschutkich aus dem Krasn...
# 199  lr lieben daa Leben dieser Titel der dem 20. J...
#
#      indexes_target_token_tokenized indexes_target_sentence_tokenized  \
# 0                                14                              0:31
# 1                                25                              0:29
# 2                                 4                              0:75
# 3                                 8                              0:10
# 4                                62                              0:77
# ..                              ...                               ...
# 195                               6                              0:24
# 196                               9                              0:17
# 197                               5                              0:11
# 198                              14                              0:22
# 199                               5                              0:27
#
#                                     context_lemmatized  \
# 0    von d ursprünglich Absicht , demselben als Ein...
# 1    sie sein dann berechtigt und stehen mit d ganz...
# 2    als ganz fundamental sein voranstellen d Satz ...
# 3    müssen ich nicht Luther selbst und d Reformati...
# 4    es können z. B. eine Philosophie eine verhältn...
# ..                                                 ...
# 195  erstmalig werden auch aktiv Sportler d Titel v...
# 196  d gut Judoka aus 18 Land streben nach d Titel ...
# 197  Mehrfach holen er sich d Titel eine Speedway-C...
# 198  sein Meister Alexander Tschutkich aus d krasno...
# 199  Lr lieben Daa Leben diese Titel d d 20. Jahres...
#
#                                            context_pos
# 0    APPR ART ADJA NN $, ADJA KOKOM NN ART NN ART N...
# 1    PPER VAFIN ADV ADJD KON VVFIN APPR ART ADJA NN...
# 2    KOKOM ADV ADJD VAFIN VVPP ART NN $. CARD $( $(...
# 3         VMFIN PPER PTKNEG NE ADV KON ART NN VVINF $.
# 4    PPER VMFIN APPRART NN ART NN ART ADV ADV ADJA ...
# ..                                                 ...
# 195  ADJD VAFIN ADV ADJA NN ART NN ADJA NN ART NN V...
# 196  ART ADJA NN APPR CARD NN VVFIN APPR ART NN $, ...
# 197          NN VVFIN PPER PRF ART NN ART NN ART NE $.
# 198  VAFIN NE NE NE APPR ART ADJA NN ART NN ART NN ...
# 199  NE VVFIN NE NN PDAT NN ART ART ADJA NN PPOSAT ...
#
# [9125 rows x 14 columns]

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from cluster_ import *

# Load word sense annotation for DWUG DE
df_dwug_de_senses = pd.DataFrame()
for p in Path(dataset_path+'/data').glob('*/judgments_senses.csv'):
    judgments = pd.read_csv(p, delimiter='\t')
    senses = pd.read_csv(str(p).replace('judgments_',''), delimiter='\t')
    judgments = pd.merge(judgments, senses, left_on='identifier_sense', right_on="identifier_sense", how ='outer')
    #judgments = judgments[~(judgments['description_sense'] == 'andere')] # remove andere instances
    #judgments['identifier_sense'] = judgments['lemma'] + judgments['identifier_sense'] # prefix senses for uniqueness across lemmas
    judgments.loc[judgments['description_sense'] == 'andere', 'identifier_sense'] = 'andere' # keep, but label them
    lemmas = judgments.groupby('identifier').agg({'lemma':lambda x: list(x)[0]})
    judgmentsA = judgments[judgments['annotator'] == 'annotatorA'][['identifier', 'identifier_sense']].rename(columns={'identifier_sense': 'annotatorA'}, inplace=False)
    judgmentsB = judgments[judgments['annotator'] == 'annotatorB'][['identifier', 'identifier_sense']].rename(columns={'identifier_sense': 'annotatorB'}, inplace=False)
    judgmentsC = judgments[judgments['annotator'] == 'annotatorC'][['identifier', 'identifier_sense']].rename(columns={'identifier_sense': 'annotatorC'}, inplace=False)
    judgments = judgments.groupby('identifier')['identifier_sense'].apply(list).reset_index(name='judgments')
    judgments = pd.merge(judgmentsC, judgments, left_on='identifier', right_on="identifier")
    judgments = pd.merge(judgmentsB, judgments, left_on='identifier', right_on="identifier")
    judgments = pd.merge(judgmentsA, judgments, left_on='identifier', right_on="identifier")
    judgments = pd.merge(lemmas, judgments, left_on='identifier', right_on="identifier")
    df_dwug_de_senses = pd.concat([df_dwug_de_senses, judgments])
display(df_dwug_de_senses)

# Extract majority labels for sense annotation
threshold = 2 # threshold for majority labels
df_dwug_de_senses['identifier_sense'] = df_dwug_de_senses['judgments'].apply(lambda x: extract_majority_label(list(x), threshold)) # add majority label column
df_dwug_de_senses['identifier_sense'] = df_dwug_de_senses['identifier_sense'].fillna(-1)
df_dwug_de_senses['identifier_sense'] = df_dwug_de_senses['identifier_sense'].replace('andere', -1)
df_dwug_de_senses['identifier_sense'] = df_dwug_de_senses['identifier_sense'].replace('None', -1)
display(df_dwug_de_senses)
# Out:
#                                    identifier    lemma annotatorA annotatorB  \
# 0      2532889X_1966-03-29_01_056.tcf.xml-3-9  Dynamik     sense2     sense2
# 1    2532889X_1969-09-03_01_021.tcf.xml-31-16  Dynamik     sense1     sense2
# 2    2532889X_1974-12-15_01_163.tcf.xml-76-16  Dynamik     sense2     sense2
# 3   2532889X_1976-05-21_01_087.tcf.xml-148-17  Dynamik     sense2     sense2
# 4     2532889X_1976-07-01_01_039.tcf.xml-9-12  Dynamik     sense2     sense2
# ..                                        ...      ...        ...        ...
# 45                  rein_japan01_1881-4452-28    Titel     sense5     sense5
# 46             robert_griechische_1881-1366-6    Titel       None     sense3
# 47              savigny_system01_1840-2586-21    Titel     sense6     sense3
# 48                   steub_tirol_1846-6476-16    Titel     sense5     sense5
# 49       treitschke_geschichte05_1894-2281-17    Titel     sense5     sense5
#
#    annotatorC                 judgments
# 0      sense2  [sense2, sense2, sense2]
# 1      sense2  [sense2, sense2, sense1]
# 2      sense2  [sense2, sense2, sense2]
# 3      sense2  [sense2, sense2, sense2]
# 4      sense2  [sense2, sense2, sense2]
# ..        ...                       ...
# 45     sense5  [sense5, sense5, sense5]
# 46       None      [None, None, sense3]
# 47     sense3  [sense6, sense3, sense3]
# 48     sense5  [sense5, sense5, sense5]
# 49     sense5  [sense5, sense5, sense5]
#
# [1200 rows x 6 columns]
#                                    identifier    lemma annotatorA annotatorB  \
# 0      2532889X_1966-03-29_01_056.tcf.xml-3-9  Dynamik     sense2     sense2
# 1    2532889X_1969-09-03_01_021.tcf.xml-31-16  Dynamik     sense1     sense2
# 2    2532889X_1974-12-15_01_163.tcf.xml-76-16  Dynamik     sense2     sense2
# 3   2532889X_1976-05-21_01_087.tcf.xml-148-17  Dynamik     sense2     sense2
# 4     2532889X_1976-07-01_01_039.tcf.xml-9-12  Dynamik     sense2     sense2
# ..                                        ...      ...        ...        ...
# 45                  rein_japan01_1881-4452-28    Titel     sense5     sense5
# 46             robert_griechische_1881-1366-6    Titel       None     sense3
# 47              savigny_system01_1840-2586-21    Titel     sense6     sense3
# 48                   steub_tirol_1846-6476-16    Titel     sense5     sense5
# 49       treitschke_geschichte05_1894-2281-17    Titel     sense5     sense5
#
#    annotatorC                 judgments identifier_sense
# 0      sense2  [sense2, sense2, sense2]           sense2
# 1      sense2  [sense2, sense2, sense1]           sense2
# 2      sense2  [sense2, sense2, sense2]           sense2
# 3      sense2  [sense2, sense2, sense2]           sense2
# 4      sense2  [sense2, sense2, sense2]           sense2
# ..        ...                       ...              ...
# 45     sense5  [sense5, sense5, sense5]           sense5
# 46       None      [None, None, sense3]               -1
# 47     sense3  [sense6, sense3, sense3]           sense3
# 48     sense5  [sense5, sense5, sense5]           sense5
# 49     sense5  [sense5, sense5, sense5]           sense5
#
# [1200 rows x 7 columns]

# %% [markdown]
# ### Merge sense with uses

# %%
# Merge data frames
df_dwug_de_senses = df_dwug_de_senses.merge(df_dwug_de_uses[['identifier', 'grouping']], how='left', left_on='identifier', right_on="identifier")
display(df_dwug_de_senses)
# Out:
#                                      identifier    lemma annotatorA  \
# 0        2532889X_1966-03-29_01_056.tcf.xml-3-9  Dynamik     sense2
# 1      2532889X_1969-09-03_01_021.tcf.xml-31-16  Dynamik     sense1
# 2      2532889X_1974-12-15_01_163.tcf.xml-76-16  Dynamik     sense2
# 3     2532889X_1976-05-21_01_087.tcf.xml-148-17  Dynamik     sense2
# 4       2532889X_1976-07-01_01_039.tcf.xml-9-12  Dynamik     sense2
# ...                                         ...      ...        ...
# 1195                  rein_japan01_1881-4452-28    Titel     sense5
# 1196             robert_griechische_1881-1366-6    Titel       None
# 1197              savigny_system01_1840-2586-21    Titel     sense6
# 1198                   steub_tirol_1846-6476-16    Titel     sense5
# 1199       treitschke_geschichte05_1894-2281-17    Titel     sense5
#
#      annotatorB annotatorC                 judgments identifier_sense  \
# 0        sense2     sense2  [sense2, sense2, sense2]           sense2
# 1        sense2     sense2  [sense2, sense2, sense1]           sense2
# 2        sense2     sense2  [sense2, sense2, sense2]           sense2
# 3        sense2     sense2  [sense2, sense2, sense2]           sense2
# 4        sense2     sense2  [sense2, sense2, sense2]           sense2
# ...         ...        ...                       ...              ...
# 1195     sense5     sense5  [sense5, sense5, sense5]           sense5
# 1196     sense3       None      [None, None, sense3]               -1
# 1197     sense3     sense3  [sense6, sense3, sense3]           sense3
# 1198     sense5     sense5  [sense5, sense5, sense5]           sense5
# 1199     sense5     sense5  [sense5, sense5, sense5]           sense5
#
#       grouping
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 1195         1
# 1196         1
# 1197         1
# 1198         1
# 1199         1
#
# [1200 rows x 8 columns]

# %%
import networkx as nx
from cluster_ import *
from itertools import combinations

node2cluster = dict(zip(df_dwug_de_senses['identifier'],df_dwug_de_senses['identifier_sense']))

node2grouping = dict(zip(df_dwug_de_senses['identifier'],df_dwug_de_senses['grouping']))
# Prepare the data
# Group by lemma
gb = df_dwug_de_senses.groupby('lemma')    
groups = gb.groups

# Run separately for each lemma
target2graph = {}
for word in groups.keys():
    print(word)
    df_group = gb.get_group(word)
    graph = nx.Graph()
    graph.add_nodes_from(df_group['identifier'])
    nx.set_node_attributes(graph, {node:{'type':'usage','grouping':str(node2grouping[node]),'cluster':node2cluster[node]} for node in graph.nodes()})   
    edge2weight = [(u,v,int(node2cluster[u] == node2cluster[v])) if (node2cluster[u]!=-1 and node2cluster[v]!=-1) else (u,v,np.nan) for (u,v) in combinations(graph.nodes(), 2)]
    graph.add_weighted_edges_from(edge2weight)   
    target2graph[word] = graph
# Out:
# Abgesang
# Armenhaus
# Dynamik
# Eintagsfliege
# Engpaß
# Fuß
# Knotenpunkt
# Manschette
# Mißklang
# Ohrwurm
# Rezeption
# Schmiere
# Seminar
# Sensation
# Spielball
# Titel
# abbauen
# abdecken
# abgebrüht
# artikulieren
# ausspannen
# packen
# zersetzen
# überspannen

# %%
from modules import *
import csv

lower_range_min=1
lower_range_max=3
upper_range_min=3
upper_range_max=5
lower_prob=0.01
upper_prob=0.1
old='1'
new='2'

stats = []
for word, graph in target2graph.items():
    general_stats = {'lemma':word}
    time_stats = get_time_stats(graph, threshold=0.5, lower_range=(int(lower_range_min), int(lower_range_max)), upper_range=(int(upper_range_min), int(upper_range_max)), lower_prob=float(lower_prob), upper_prob=float(upper_prob), old=old, new=new)
    period_stats = {'grouping': '{0}_{1}'.format(old, new)}
    stats.append(general_stats | period_stats | time_stats)

# Export stats
stats_output = output_path + '/stats/maj_{0}'.format(threshold)
Path(stats_output).mkdir(parents=True, exist_ok=True)
with open(stats_output+'/stats_groupings.csv'.format(threshold), 'w') as f:  
    w = csv.DictWriter(f, stats[0].keys(), delimiter='\t', quoting = csv.QUOTE_NONE, quotechar='')
    w.writeheader()
    w.writerows(stats)

# %%
# Get general statistics

stats = []
gb = df_dwug_de_senses.groupby('lemma')    
groups = gb.groups
for word in groups.keys():
    general_stats = {'lemma':word}
    #print(word)
    df_group = gb.get_group(word)
    general_stats['uses'] = df_group.shape[0]
    general_stats['excluded_uses'] = df_group['identifier_sense'].eq(-1).sum()
    stats.append(general_stats)

print(stats)   
# Export stats
stats_output = output_path + '/stats/maj_{0}'.format(threshold)
Path(stats_output).mkdir(parents=True, exist_ok=True)
with open(stats_output+'/stats.csv'.format(threshold), 'w') as f:  
    w = csv.DictWriter(f, stats[0].keys(), delimiter='\t', quoting = csv.QUOTE_NONE, quotechar='')
    w.writeheader()
    w.writerows(stats)
# Out:
# [{'lemma': 'Abgesang', 'uses': 50, 'excluded_uses': 9}, {'lemma': 'Armenhaus', 'uses': 50, 'excluded_uses': 0}, {'lemma': 'Dynamik', 'uses': 50, 'excluded_uses': 0}, {'lemma': 'Eintagsfliege', 'uses': 50, 'excluded_uses': 5}, {'lemma': 'Engpaß', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'Fuß', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'Knotenpunkt', 'uses': 50, 'excluded_uses': 10}, {'lemma': 'Manschette', 'uses': 50, 'excluded_uses': 1}, {'lemma': 'Mißklang', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'Ohrwurm', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'Rezeption', 'uses': 50, 'excluded_uses': 1}, {'lemma': 'Schmiere', 'uses': 50, 'excluded_uses': 5}, {'lemma': 'Seminar', 'uses': 50, 'excluded_uses': 5}, {'lemma': 'Sensation', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'Spielball', 'uses': 50, 'excluded_uses': 0}, {'lemma': 'Titel', 'uses': 50, 'excluded_uses': 14}, {'lemma': 'abbauen', 'uses': 50, 'excluded_uses': 1}, {'lemma': 'abdecken', 'uses': 50, 'excluded_uses': 4}, {'lemma': 'abgebrüht', 'uses': 50, 'excluded_uses': 1}, {'lemma': 'artikulieren', 'uses': 50, 'excluded_uses': 3}, {'lemma': 'ausspannen', 'uses': 50, 'excluded_uses': 2}, {'lemma': 'packen', 'uses': 50, 'excluded_uses': 10}, {'lemma': 'zersetzen', 'uses': 50, 'excluded_uses': 0}, {'lemma': 'überspannen', 'uses': 50, 'excluded_uses': 2}]

# %%
# Extract clusters
gb = df_dwug_de_senses.groupby('lemma')    
groups = gb.groups
for word in groups.keys():
    df_group = gb.get_group(word)
    n2c = dict(zip(df_group['identifier'].to_list(),df_group['identifier_sense'].to_list()))
    output_data = [{'identifier':n, 'cluster':c} for n, c in n2c.items()]  
    
    # Export data
    stats_output = '{0}/clusters/maj_{1}'.format(output_path,threshold)
    Path(stats_output).mkdir(parents=True, exist_ok=True)
    with open(stats_output+'/{0}.csv'.format(word), 'w') as f:  
        w = csv.DictWriter(f, ['identifier', 'cluster'], delimiter='\t', quoting = csv.QUOTE_NONE, quotechar='')
        w.writeheader()
        w.writerows(output_data)

# %%
# %matplotlib inline
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
nice_colors = [x for x in mcolors.get_named_colors_mapping().values() if isinstance(x, str)] # Nice colors
colors_global = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00'] # color-blind colors
colors_global = colors_global + nice_colors
         
for word, graph in target2graph.items():
    graph = graph.copy()
    print(word)
    print(graph)
    enan=[(u,v) for (u,v,d) in graph.edges(data=True) if np.isnan(d['weight'])]
    graph.remove_edges_from(enan) # Remove nan edges for finding positions        
    # we remove isolated nodes
    graph.remove_nodes_from(list(nx.isolates(graph)))

    # Draw graph
    nx.draw(graph, with_labels=False, font_weight='bold', node_color=np.array(colors_global)[[int(node2cluster[node].replace('sense', '')) for node in graph.nodes()]])
# Out:
# Abgesang
# Graph with 50 nodes and 1225 edges
# Armenhaus
# Graph with 50 nodes and 1225 edges
# Dynamik
# Graph with 50 nodes and 1225 edges
# Eintagsfliege
# Graph with 50 nodes and 1225 edges
# Engpaß
# Graph with 50 nodes and 1225 edges
# Fuß
# Graph with 50 nodes and 1225 edges
# Knotenpunkt
# Graph with 50 nodes and 1225 edges
# Manschette
# Graph with 50 nodes and 1225 edges
# Mißklang
# Graph with 50 nodes and 1225 edges
# Ohrwurm
# Graph with 50 nodes and 1225 edges
# Rezeption
# Graph with 50 nodes and 1225 edges
# Schmiere
# Graph with 50 nodes and 1225 edges
# Seminar
# Graph with 50 nodes and 1225 edges
# Sensation
# Graph with 50 nodes and 1225 edges
# Spielball
# Graph with 50 nodes and 1225 edges
# Titel
# Graph with 50 nodes and 1225 edges
# abbauen
# Graph with 50 nodes and 1225 edges
# abdecken
# Graph with 50 nodes and 1225 edges
# abgebrüht
# Graph with 50 nodes and 1225 edges
# artikulieren
# Graph with 50 nodes and 1225 edges
# ausspannen
# Graph with 50 nodes and 1225 edges
# packen
# Graph with 50 nodes and 1225 edges
# zersetzen
# Graph with 50 nodes and 1225 edges
# überspannen
# Graph with 50 nodes and 1225 edges

# %%
from sklearn.metrics import cohen_kappa_score, hamming_loss, accuracy_score
import krippendorff_ as krippendorff
import csv

stats = []
annotators = ['annotatorA', 'annotatorB', 'annotatorC']
df = df_dwug_de_senses[annotators + ['lemma']].replace('None', np.nan).replace('andere', np.nan)
df_ = pd.DataFrame()  
df_['lemma'] = df['lemma']
df_[annotators[0]] = df['lemma'] + df[annotators[0]] # prefix senses for uniqueness
df_[annotators[1]] = df['lemma'] + df[annotators[1]]
df_[annotators[2]] = df['lemma'] + df[annotators[2]]
display(df_)
stacked = df_[[annotators[0], annotators[1], annotators[2]]].stack()
df_[[annotators[0], annotators[1], annotators[2]]] = pd.Series(stacked.factorize()[0], index=stacked.index).unstack()
display(df_)
df = df_

stats_agree = {}

# Krippendorff     
# Full data   
data = np.transpose(df.loc[:, annotators[0]:annotators[-1]].values)
kri = krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')
print('full', kri)
stats_agree['kri_full'] = kri

# Pairwise
for a, b in combinations(annotators, 2):
    data = [df[a].values, df[b].values]
    kri = krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')
    print('full', a, b, kri)
    stats_agree['kri_{0},{1}'.format(a, b)] = kri

# Cohen's kappa and Percentage Agreement
for metric, name in [(cohen_kappa_score, 'cohen_kappa'), (lambda x,y: 1-hamming_loss(x, y), 'ita')]:
    scores = []
    for a, b in combinations(annotators, 2):
        data = df[~df[a].isnull() & ~df[b].isnull()]
        data_a = data[a]
        data_b = data[b]
        if name == 'kri':
            score = metric([data_a, data_b])
        else:            
            score = metric(data_a, data_b)
        print('full', a, b, score)
        scores.append(score)
        stats_agree['{0}_{1},{2}'.format(name, a, b)] = score

    mean = np.mean(scores)    
    print('mean', mean)
    stats_agree['{0}_mean'.format(name)] = mean    

# first some general statistics
stats_agree['judgments_None'] = df_dwug_de_senses[[annotators[0], annotators[1], annotators[2]]].stack().eq('None').sum()
stats_agree['judgments_others'] = df_dwug_de_senses[[annotators[0], annotators[1], annotators[2]]].stack().eq('andere').sum()
stats_agree['judgments_total'] = (df_dwug_de_senses[[annotators[0], annotators[1], annotators[2]]].stack() != 'None').sum()    
    
    
stats.append({'data':'full'} | stats_agree)


# By lemma
scores = []
stats_agree = {}
gb = df.groupby('lemma')
groups = gb.groups
# also group non-processed data frame
gb_full = df_dwug_de_senses.groupby('lemma')
groups_full = gb_full.groups
for word in groups.keys():
    
    df_group = gb.get_group(word)

    data = np.transpose(df_group.loc[:, annotators[0]:annotators[-1]].values)
    kri = krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')
    print(word, kri)
    stats_agree['kri_full'] = kri
    for a, b in combinations(annotators, 2):
        data = [df_group[a].values, df_group[b].values]
        kri = krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')
        print(word, a, b, kri)
        stats_agree['kri_{0},{1}'.format(a, b)] = kri
    
    for metric, name in [(cohen_kappa_score, 'cohen_kappa'), (lambda x,y: 1-hamming_loss(x, y), 'ita')]:
        scores = []
        for a, b in combinations(annotators, 2):
            data = df_group[~df_group[a].isnull() & ~df_group[b].isnull()]
            score = metric(data[a], data[b])
            print(word, a, b, score)
            scores.append(score)
            stats_agree['{0}_{1},{2}'.format(name, a, b)] = score

        mean = np.nanmean(scores)    
        print('mean', mean)
        stats_agree['{0}_mean'.format(name)] = mean
    
    # some general statistics
    df_group_full = gb_full.get_group(word)
    stats_agree['judgments_None'] = df_group_full[[annotators[0], annotators[1], annotators[2]]].stack().eq('None').sum()
    stats_agree['judgments_others'] = df_group_full[[annotators[0], annotators[1], annotators[2]]].stack().eq('andere').sum()
    stats_agree['judgments_total'] = (df_group_full[[annotators[0], annotators[1], annotators[2]]].stack() != 'None').sum()    
    stats.append({'data':word} | stats_agree)
   
    
# Export stats
stats_output = output_path + '/stats'
Path(stats_output).mkdir(parents=True, exist_ok=True)
with open(stats_output+'/stats_agreement.csv', 'w') as f:  
    w = csv.DictWriter(f, stats[0].keys(), delimiter='\t', quoting = csv.QUOTE_NONE, quotechar='')
    w.writeheader()
    w.writerows(stats)
# Out:
#         lemma     annotatorA     annotatorB     annotatorC
# 0     Dynamik  Dynamiksense2  Dynamiksense2  Dynamiksense2
# 1     Dynamik  Dynamiksense1  Dynamiksense2  Dynamiksense2
# 2     Dynamik  Dynamiksense2  Dynamiksense2  Dynamiksense2
# 3     Dynamik  Dynamiksense2  Dynamiksense2  Dynamiksense2
# 4     Dynamik  Dynamiksense2  Dynamiksense2  Dynamiksense2
# ...       ...            ...            ...            ...
# 1195    Titel    Titelsense5    Titelsense5    Titelsense5
# 1196    Titel            NaN    Titelsense3            NaN
# 1197    Titel    Titelsense6    Titelsense3    Titelsense3
# 1198    Titel    Titelsense5    Titelsense5    Titelsense5
# 1199    Titel    Titelsense5    Titelsense5    Titelsense5
#
# [1200 rows x 4 columns]
#         lemma  annotatorA  annotatorB  annotatorC
# 0     Dynamik         0.0         0.0         0.0
# 1     Dynamik         1.0         0.0         0.0
# 2     Dynamik         0.0         0.0         0.0
# 3     Dynamik         0.0         0.0         0.0
# 4     Dynamik         0.0         0.0         0.0
# ...       ...         ...         ...         ...
# 1195    Titel        72.0        72.0        72.0
# 1196    Titel         NaN        76.0         NaN
# 1197    Titel        75.0        76.0        76.0
# 1198    Titel        72.0        72.0        72.0
# 1199    Titel        72.0        72.0        72.0
#
# [1200 rows x 4 columns]
# full 0.8674022038182758
# full annotatorA annotatorB 0.8447226713092721
# full annotatorA annotatorC 0.8874716338167626
# full annotatorB annotatorC 0.8865034881789365
# full annotatorA annotatorB 0.8447351696185531
# full annotatorA annotatorC 0.8874646565531322
# full annotatorB annotatorC 0.8864799312186071
# mean 0.8728932524634309
# full annotatorA annotatorB 0.847985347985348
# full annotatorA annotatorC 0.889990089197225
# full annotatorB annotatorC 0.8889934148635936
# mean 0.8756562840153889
# Abgesang 0.7749546279491832
# Abgesang annotatorA annotatorB 0.7033333333333334
# Abgesang annotatorA annotatorC 1.0
# Abgesang annotatorB annotatorC 0.8402777777777778
# Abgesang annotatorA annotatorB 0.7026431718061674
# Abgesang annotatorA annotatorC 1.0
# Abgesang annotatorB annotatorC 0.837962962962963
# mean 0.8468687115897101
# Abgesang annotatorA annotatorB 0.8666666666666667
# Abgesang annotatorA annotatorC 1.0
# Abgesang annotatorB annotatorC 0.9428571428571428
# mean 0.9365079365079364
# Armenhaus 1.0
# Armenhaus annotatorA annotatorB 1.0
# Armenhaus annotatorA annotatorC 1.0
# Armenhaus annotatorB annotatorC 1.0
# Armenhaus annotatorA annotatorB 1.0
# Armenhaus annotatorA annotatorC 1.0
# Armenhaus annotatorB annotatorC 1.0
# mean 1.0
# Armenhaus annotatorA annotatorB 1.0
# Armenhaus annotatorA annotatorC 1.0
# Armenhaus annotatorB annotatorC 1.0
# mean 1.0
# Dynamik 0.6427672955974844
# Dynamik annotatorA annotatorB 0.5995316159250585
# Dynamik annotatorA annotatorC 0.6598056032018296
# Dynamik annotatorB annotatorC 0.6260504201680672
# Dynamik annotatorA annotatorB 0.5970149253731343
# Dynamik annotatorA annotatorC 0.6606538895152199
# Dynamik annotatorB annotatorC 0.6226415094339622
# mean 0.6267701081074387
# Dynamik annotatorA annotatorB 0.8125
# Dynamik annotatorA annotatorC 0.8372093023255813
# Dynamik annotatorB annotatorC 0.8222222222222222
# mean 0.8239771748492678
# Eintagsfliege 0.9074252651880425
# Eintagsfliege annotatorA annotatorB 0.9010025062656641
# Eintagsfliege annotatorA annotatorC 0.8986842105263158
# Eintagsfliege annotatorB annotatorC 0.9099378881987578
# Eintagsfliege annotatorA annotatorB 0.899749373433584
# Eintagsfliege annotatorA annotatorC 0.8973684210526316
# Eintagsfliege annotatorB annotatorC 0.9089026915113871
# mean 0.9020068286658676
# Eintagsfliege annotatorA annotatorB 0.95
# Eintagsfliege annotatorA annotatorC 0.9487179487179487
# Eintagsfliege annotatorB annotatorC 0.9545454545454546
# mean 0.9510878010878011
# Engpaß 0.9171461449942463
# Engpaß annotatorA annotatorB 0.9583150504607284
# Engpaß annotatorA annotatorC 0.9148351648351648
# Engpaß annotatorB annotatorC 0.916958041958042
# Engpaß annotatorA annotatorB 0.9578947368421052
# Engpaß annotatorA annotatorC 0.9139194139194139
# Engpaß annotatorB annotatorC 0.916083916083916
# mean 0.9292993556151451
# Engpaß annotatorA annotatorB 0.9791666666666666
# Engpaß annotatorA annotatorC 0.9574468085106383
# Engpaß annotatorB annotatorC 0.9583333333333334
# mean 0.9649822695035462
# Fuß 0.9178680646570555
# Fuß annotatorA annotatorB 0.9377718300434928
# Fuß annotatorA annotatorC 0.9665187575635337
# Fuß annotatorB annotatorC 0.9059859154929577
# Fuß annotatorA annotatorB 0.9371657754010695
# Fuß annotatorA annotatorC 0.9661290322580645
# Fuß annotatorB annotatorC 0.9049964813511612
# mean 0.9360970963367651
# Fuß annotatorA annotatorB 0.9574468085106383
# Fuß annotatorA annotatorC 0.9761904761904762
# Fuß annotatorB annotatorC 0.9333333333333333
# mean 0.9556568726781492
# Knotenpunkt 0.2642019837691614
# Knotenpunkt annotatorA annotatorB 0.12854757929883143
# Knotenpunkt annotatorA annotatorC 0.8381374722838137
# Knotenpunkt annotatorB annotatorC 0.05245901639344264
# Knotenpunkt annotatorA annotatorB 0.24714828897338403
# Knotenpunkt annotatorA annotatorC 0.8370044052863437
# Knotenpunkt annotatorB annotatorC 0.16457142857142848
# mean 0.41624137427705205
# Knotenpunkt annotatorA annotatorB 0.5909090909090908
# Knotenpunkt annotatorA annotatorC 0.9189189189189189
# Knotenpunkt annotatorB annotatorC 0.6046511627906976
# mean 0.7048263908729023
# Manschette 0.8154746754899466
# Manschette annotatorA annotatorB 0.7837222538417757
# Manschette annotatorA annotatorC 0.8577013291634089
# Manschette annotatorB annotatorC 0.8257946210268949
# Manschette annotatorA annotatorB 0.7820658342792282
# Manschette annotatorA annotatorC 0.85625
# Manschette annotatorB annotatorC 0.824390243902439
# mean 0.8209020260605557
# Manschette annotatorA annotatorB 0.9166666666666666
# Manschette annotatorA annotatorC 0.9565217391304348
# Manschette annotatorB annotatorC 0.9375
# mean 0.9368961352657005
# Mißklang 0.5704779189352692
# Mißklang annotatorA annotatorB 0.5921052631578947
# Mißklang annotatorA annotatorC 0.6044444444444443
# Mißklang annotatorB annotatorC 0.5303030303030303
# Mißklang annotatorA annotatorB 0.5924855491329479
# Mißklang annotatorA annotatorC 0.6003552397868561
# Mißklang annotatorB annotatorC 0.53
# mean 0.5742802629732681
# Mißklang annotatorA annotatorB 0.8723404255319149
# Mißklang annotatorA annotatorC 0.8888888888888888
# Mißklang annotatorB annotatorC 0.8297872340425532
# mean 0.863672182821119
# Ohrwurm 1.0
# Ohrwurm annotatorA annotatorB 1.0
# Ohrwurm annotatorA annotatorC 1.0
# Ohrwurm annotatorB annotatorC 1.0
# Ohrwurm annotatorA annotatorB 1.0
# Ohrwurm annotatorA annotatorC 1.0
# Ohrwurm annotatorB annotatorC 1.0
# mean 1.0
# Ohrwurm annotatorA annotatorB 1.0
# Ohrwurm annotatorA annotatorC 1.0
# Ohrwurm annotatorB annotatorC 1.0
# mean 1.0
# Rezeption 0.7705426356589147
# Rezeption annotatorA annotatorB 0.8350340136054422
# Rezeption annotatorA annotatorC 0.8986415882967607
# Rezeption annotatorB annotatorC 0.6710963455149501
# Rezeption annotatorA annotatorB 0.8338983050847457
# Rezeption annotatorA annotatorC 0.8977035490605428
# Rezeption annotatorB annotatorC 0.6721311475409836
# mean 0.8012443338954242
# Rezeption annotatorA annotatorB 0.9591836734693877
# Rezeption annotatorA annotatorC 0.9795918367346939
# Rezeption annotatorB annotatorC 0.92
# mean 0.9529251700680272
# Schmiere 0.8152173913043479
# Schmiere annotatorA annotatorB 0.8462448255470136
# Schmiere annotatorA annotatorC 0.7616136919315404
# Schmiere annotatorB annotatorC 0.8064516129032258
# Schmiere annotatorA annotatorB 0.8441558441558441
# Schmiere annotatorA annotatorC 0.7602905569007263
# Schmiere annotatorB annotatorC 0.8050541516245487
# mean 0.8031668508937063
# Schmiere annotatorA annotatorB 0.8787878787878788
# Schmiere annotatorA annotatorC 0.8181818181818181
# Schmiere annotatorB annotatorC 0.8666666666666667
# mean 0.8545454545454545
# Seminar 0.6062597267854055
# Seminar annotatorA annotatorB 0.6292134831460674
# Seminar annotatorA annotatorC 0.5765570934256056
# Seminar annotatorB annotatorC 0.6239966201943388
# Seminar annotatorA annotatorB 0.6267148014440433
# Seminar annotatorA annotatorC 0.5747422680412371
# Seminar annotatorB annotatorC 0.625
# mean 0.6088190231617602
# Seminar annotatorA annotatorB 0.7659574468085106
# Seminar annotatorA annotatorC 0.7555555555555555
# Seminar annotatorB annotatorC 0.7777777777777778
# mean 0.7664302600472813
# Sensation 0.4288340336134454
# Sensation annotatorA annotatorB 0.4696969696969697
# Sensation annotatorA annotatorC 0.3308823529411765
# Sensation annotatorB annotatorC 0.5580357142857143
# Sensation annotatorA annotatorB 0.49339207048458156
# Sensation annotatorA annotatorC 0.3783783783783784
# Sensation annotatorB annotatorC 0.5588235294117647
# mean 0.47686465942490824
# Sensation annotatorA annotatorB 0.782608695652174
# Sensation annotatorA annotatorC 0.7391304347826086
# Sensation annotatorB annotatorC 0.88
# mean 0.8005797101449276
# Spielball 0.6549295774647887
# Spielball annotatorA annotatorB 0.484375
# Spielball annotatorA annotatorC 0.6594982078853047
# Spielball annotatorB annotatorC 0.7912087912087913
# Spielball annotatorA annotatorB 0.48453608247422675
# Spielball annotatorA annotatorC 0.6571428571428571
# Spielball annotatorB annotatorC 0.7894736842105263
# mean 0.6437175412758701
# Spielball annotatorA annotatorB 0.96
# Spielball annotatorA annotatorC 0.9791666666666666
# Spielball annotatorB annotatorC 0.9791666666666666
# mean 0.9727777777777776
# Titel 0.7464872944693572
# Titel annotatorA annotatorB 0.7554925584691707
# Titel annotatorA annotatorC 0.7044117647058823
# Titel annotatorB annotatorC 0.8005952380952381
# Titel annotatorA annotatorB 0.7524752475247525
# Titel annotatorA annotatorC 0.7008797653958944
# Titel annotatorB annotatorC 0.798219584569733
# mean 0.7505248658301267
# Titel annotatorA annotatorB 0.8571428571428572
# Titel annotatorA annotatorC 0.8235294117647058
# Titel annotatorB annotatorC 0.8823529411764706
# mean 0.8543417366946778
# abbauen 0.8489358535496354
# abbauen annotatorA annotatorB 0.8051282051282052
# abbauen annotatorA annotatorC 0.9654403567447045
# abbauen annotatorB annotatorC 0.7984104046242775
# abbauen annotatorA annotatorB 0.8035470668485676
# abbauen annotatorA annotatorC 0.9650817236255572
# abbauen annotatorB annotatorC 0.7971223021582734
# mean 0.8552503642107995
# abbauen annotatorA annotatorB 0.875
# abbauen annotatorA annotatorC 0.9787234042553191
# abbauen annotatorB annotatorC 0.8723404255319149
# mean 0.9086879432624113
# abdecken 0.5666718774425512
# abdecken annotatorA annotatorB 0.4117469879518072
# abdecken annotatorA annotatorC 0.7947761194029851
# abdecken annotatorB annotatorC 0.4502617801047121
# abdecken annotatorA annotatorB 0.41975308641975306
# abdecken annotatorA annotatorC 0.7925531914893618
# abdecken annotatorB annotatorC 0.4734473447344735
# mean 0.5619178742145294
# abdecken annotatorA annotatorB 0.5531914893617021
# abdecken annotatorA annotatorC 0.8717948717948718
# abdecken annotatorB annotatorC 0.6153846153846154
# mean 0.6801236588470632
# abgebrüht 0.972972972972973
# abgebrüht annotatorA annotatorB 0.9596001665972511
# abgebrüht annotatorA annotatorC 1.0
# abgebrüht annotatorB annotatorC 0.9596001665972511
# abgebrüht annotatorA annotatorB 0.9592006661115737
# abgebrüht annotatorA annotatorC 1.0
# abgebrüht annotatorB annotatorC 0.9592006661115737
# mean 0.9728004440743825
# abgebrüht annotatorA annotatorB 0.9795918367346939
# abgebrüht annotatorA annotatorC 1.0
# abgebrüht annotatorB annotatorC 0.9795918367346939
# mean 0.9863945578231292
#             lemma  annotatorA  annotatorB  annotatorC
# 100  artikulieren         6.0         6.0         6.0
# 101  artikulieren         6.0         6.0         6.0
# 102  artikulieren         6.0         6.0         6.0
# 103  artikulieren         6.0         6.0         6.0
# 104  artikulieren         6.0         6.0         6.0
# 105  artikulieren         6.0         6.0         6.0
# 106  artikulieren         6.0         6.0         6.0
# 107  artikulieren         6.0         6.0         6.0
# 108  artikulieren         6.0         6.0         6.0
# 109  artikulieren         6.0         6.0         6.0
# 110  artikulieren         6.0         6.0         NaN
# 111  artikulieren         6.0         6.0         6.0
# 112  artikulieren         6.0         6.0         6.0
# 113  artikulieren         6.0         6.0         6.0
# 114  artikulieren         6.0         6.0         6.0
# 115  artikulieren         6.0         6.0         6.0
# 116  artikulieren         6.0         6.0         6.0
# 117  artikulieren         6.0         6.0         6.0
# 118  artikulieren         6.0         6.0         6.0
# 119  artikulieren         6.0         6.0         6.0
# 120  artikulieren         6.0         6.0         NaN
# 121  artikulieren         6.0         6.0         NaN
# 122  artikulieren         6.0         6.0         6.0
# 123  artikulieren         6.0         6.0         6.0
# 124  artikulieren         7.0         6.0         NaN
# 125  artikulieren         6.0         6.0         6.0
# 126  artikulieren         7.0         7.0         NaN
# 127  artikulieren         7.0         NaN         NaN
# 128  artikulieren         7.0         7.0         NaN
# 129  artikulieren         7.0         NaN         NaN
# 130  artikulieren         7.0         7.0         NaN
# 131  artikulieren         7.0         7.0         NaN
# 132  artikulieren         7.0         7.0         NaN
# 133  artikulieren         7.0         7.0         NaN
# 134  artikulieren         6.0         6.0         6.0
# 135  artikulieren         6.0         6.0         6.0
# 136  artikulieren         6.0         6.0         6.0
# 137  artikulieren         6.0         6.0         6.0
# 138  artikulieren         6.0         6.0         6.0
# 139  artikulieren         6.0         6.0         6.0
# 140  artikulieren         7.0         6.0         6.0
# 141  artikulieren         7.0         7.0         NaN
# 142  artikulieren         7.0         7.0         NaN
# 143  artikulieren         7.0         7.0         NaN
# 144  artikulieren         7.0         7.0         NaN
# 145  artikulieren         6.0         6.0         NaN
# 146  artikulieren         6.0         6.0         6.0
# 147  artikulieren         7.0         7.0         NaN
# 148  artikulieren         6.0         6.0         6.0
# 149  artikulieren         6.0         6.0         6.0
# artikulieren 0.8982371794871795
# artikulieren annotatorA annotatorB 0.8900462962962963
# artikulieren annotatorA annotatorC 0.0
# artikulieren annotatorB annotatorC nan
# artikulieren annotatorA annotatorB 0.8891454965357968
# artikulieren annotatorA annotatorC 0.0
# artikulieren annotatorB annotatorC nan
# mean 0.4445727482678984
# artikulieren annotatorA annotatorB 0.9583333333333334
# artikulieren annotatorA annotatorC 0.96875
# artikulieren annotatorB annotatorC 1.0
# mean 0.9756944444444445
# ausspannen 0.8297613619091048
# ausspannen annotatorA annotatorB 0.810568295114656
# ausspannen annotatorA annotatorC 0.8959608323133414
# ausspannen annotatorB annotatorC 0.801445416508178
# ausspannen annotatorA annotatorB 0.8087649402390438
# ausspannen annotatorA annotatorC 0.8950366151342555
# ausspannen annotatorB annotatorC 0.8
# mean 0.8346005184577665
# ausspannen annotatorA annotatorB 0.875
# ausspannen annotatorA annotatorC 0.9302325581395349
# ausspannen annotatorB annotatorC 0.8636363636363636
# mean 0.8896229739252995
# packen 0.8447390932420873
# packen annotatorA annotatorB 0.8806045340050378
# packen annotatorA annotatorC 0.8619079386257505
# packen annotatorB annotatorC 0.9143192488262911
# packen annotatorA annotatorB 0.8793969849246231
# packen annotatorA annotatorC 0.8601864181091877
# packen annotatorB annotatorC 0.9132473622508792
# mean 0.8842769217615634
# packen annotatorA annotatorB 0.925
# packen annotatorA annotatorC 0.9142857142857143
# packen annotatorB annotatorC 0.9459459459459459
# mean 0.9284105534105535
# zersetzen 0.2556264066016505
# zersetzen annotatorA annotatorB -0.24747474747474763
# zersetzen annotatorA annotatorC -0.272952853598015
# zersetzen annotatorB annotatorC 0.9590739975196362
# zersetzen annotatorA annotatorB 0.023474178403755874
# zersetzen annotatorA annotatorC 0.018181818181818188
# zersetzen annotatorB annotatorC 0.9586776859504132
# mean 0.3334445608453291
# zersetzen annotatorA annotatorB 0.45833333333333337
# zersetzen annotatorA annotatorC 0.4375
# zersetzen annotatorB annotatorC 0.98
# mean 0.6252777777777778
# überspannen 0.546975546975547
# überspannen annotatorA annotatorB 0.42739726027397273
# überspannen annotatorA annotatorC 0.6040044493882091
# überspannen annotatorB annotatorC 0.6050826946349335
# überspannen annotatorA annotatorB 0.4382022471910112
# überspannen annotatorA annotatorC 0.6
# überspannen annotatorB annotatorC 0.6162790697674418
# mean 0.5514937723194844
# überspannen annotatorA annotatorB 0.62
# überspannen annotatorA annotatorC 0.7333333333333334
# überspannen annotatorB annotatorC 0.7555555555555555
# mean 0.702962962962963
# /mount/projekte50/projekte/cik/users/dominik/WUGs/scripts/misc/../krippendorff_.py:296: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (o * d).sum() / (e * d).sum()
# /usr/lib64/python3.10/site-packages/sklearn/metrics/_classification.py:658: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)

# %%
# Export annotators
annotators_out = [{'annotator': annotator} for annotator in annotators]
stats_output = output_path 
Path(stats_output).mkdir(parents=True, exist_ok=True)
with open(stats_output+'/annotators.csv', 'w') as f:  
    w = csv.DictWriter(f, annotators_out[0].keys(), delimiter='\t', quoting = csv.QUOTE_NONE, quotechar='')
    w.writeheader()
    w.writerows(annotators_out)
